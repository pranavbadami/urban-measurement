# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
data = pd.read_csv('valid.txt', header=None)
data.columns = ['ID', 'Time', 'Status', 'Latitude', 'NS', 'Longitude', 'EW', 'Knots', 'Other', 'Date', 'Other1', 'Other 2', 'Other3']

# %%
data['']
# Out:
#           ID      Time Status   Latitude NS  Longitude EW  Knots   Other  \
# 0    ﻿$GPRMC  235052.0      A  4020.8631  N  7439.6255  W   0.30   51.76
# 1     $GPRMC  235053.0      A  4020.8646  N  7439.6235  W   0.03   60.30
# 2     $GPRMC  235054.0      A  4020.8651  N  7439.6231  W   0.02  218.11
# 3     $GPRMC  235055.0      A  4020.8772  N  7439.6064  W   0.03   45.48
# 4     $GPRMC  235056.0      A  4020.8800  N  7439.6026  W   0.01  108.22
# 5     $GPRMC  235057.0      A  4020.8829  N  7439.5985  W   0.02   28.30
# 6     $GPRMC  235058.0      A  4020.8834  N  7439.5978  W   0.05   43.65
# 7     $GPRMC  235059.0      A  4020.8843  N  7439.5966  W   0.01   59.36
# 8     $GPRMC  235100.0      A  4020.8846  N  7439.5961  W   0.03   52.69
# 9     $GPRMC  235101.0      A  4020.8846  N  7439.5961  W   0.02   41.01
# 10    $GPRMC  235102.0      A  4020.8848  N  7439.5958  W   0.03  247.85
# 11    $GPRMC  235103.0      A  4020.8846  N  7439.5959  W   0.02   68.85
# ...

# %%
data.plot(kind="scatter", y="Latitude", x="Longitude")
